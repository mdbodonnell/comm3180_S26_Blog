# %% [raw]
# ---
# title: "Dataset of the Week #1: The Weather in Philadelphia"
# author: Matt
# date: 1/28/2026
# categories:
#    - DOW
#    - weather
# ---

# %% [markdown]
# ### Did the groundhog get it right in Philly?
#
# ![](groundhog.png){width=200}

# %%
import pandas as pd

# %%
weather_df = pd.read_csv('data/philadelphia_weather_2005_to_2025.csv')

# %% [markdown]
# ### What was the weather in Philly GH day from 2005 to 2025?
#
# * Good question!!!!

# %%
weather_df.query('day=="February 2"')[['year','low','high']]
# Out:
#       year  low  high
# 32    2005   16    41
# 397   2006   31    55
# 762   2007   30    40
# 1127  2008   31    44
# 1493  2009   30    54
# 1858  2010   22    36
# 2223  2011   30    42
# 2588  2012   39    51
# 2954  2013   18    30
# 3319  2014   29    53
# 3684  2015   23    41
# 4049  2016   34    53
# 4415  2017   34    48
# 4780  2018   20    40
# 5145  2019   11    31
# 5510  2020   34    43
# 5876  2021   30    36
# 6241  2022   25    46
# 6606  2023   28    41
# 6971  2024   40    46
# 7337  2025   19    38
